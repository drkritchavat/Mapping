# %%
def run3():
    # %run ./Step3_Areacode.ipynb
def click2(none):
    df = pd.read_excel(my_button.files[0])
    print("ตัวอย่างตารางข้อมูล")
    print(df[:10])
    print("ตารางข้อมูลนี้มีทั้งหมด " +  str(len(list(df.columns))) + " ตัวแปร ได้แก่")
    for index, item in enumerate(list(df.columns)):
        print(str(index+1)+". " + item)
    run3()
    

    
    
    #%run ./Step3_Areacode.ipynb
class SelectFilesButton(widgets.Button):
    """A file widget that leverages tkinter.filedialog."""

    def __init__(self,input):
        self.input = input
        super(SelectFilesButton, self).__init__()
        # Add the selected_files trait
        self.add_traits(files=traitlets.traitlets.List())
        # Create the button.
        self.description = "Select Files"
        self.icon = "square-o"
        self.style.button_color = "orange"
        # Set on click behavior.
        #self.on_click(self.select_files)
        

    @staticmethod
    def select_files(b):
        """Generate instance of tkinter.filedialog.

        Parameters
        ----------
        b : obj:
            An instance of ipywidgets.widgets.Button 
        """
        # Create Tk root
        root = Tk()
        # Hide the main window
        root.withdraw()
        # Raise the root to the top of all windows.
        root.call('wm', 'attributes', '.', '-topmost', True)
        # List of selected fileswill be set to b.value
        b.files = filedialog.askopenfilename(multiple=True)

        b.description = "Files Selected"
        b.icon = "check-square-o"
        b.style.button_color = "lightgreen"
        
if selectarea.value == 'Province':
    print("Province map")
    geo = './GeoJSON/new/province.json'
    mapcode = 'PROVINCE'
    tooltipvar = ['ENAME']
    alias = ['Province']
elif selectarea.value == 'District':
    print("District map")
    geo = './GeoJSON/new/district.json'
    mapcode = 'CODE'
    tooltipvar = ['ENAME','ENAME0']
    alias = ['District','Province']

my_button = SelectFilesButton(input)
display(my_button)
my_button.on_click(my_button.select_files)

button2 = widgets.Button(description="Next Step")
display(button2)
button2.on_click(click2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0f7ec0d3b108> in <module>
#      12
#      13     #%run ./Step3_Areacode.ipynb
# ---> 14 class SelectFilesButton(widgets.Button):
#      15     """A file widget that leverages tkinter.filedialog."""
#      16
#
# NameError: name 'widgets' is not defined
